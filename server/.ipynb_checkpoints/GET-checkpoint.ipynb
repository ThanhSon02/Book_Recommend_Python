# %%
import numpy as np
import pandas as pd

# %%
users_df = pd.read_csv('Users.csv')
users_df = users_df.dropna()
users_df
# Out:
#         User-ID                            Location   Age
# 1             2           stockton, california, usa  18.0
# 3             4           porto, v.n.gaia, portugal  17.0
# 5             6       santa monica, california, usa  61.0
# 9            10          albacete, wisconsin, spain  26.0
# 10           11      melbourne, victoria, australia  14.0
# ...         ...                                 ...   ...
# 278848   278849         georgetown, ontario, canada  23.0
# 278850   278851                  dallas, texas, usa  33.0
# 278851   278852     brisbane, queensland, australia  32.0
# 278852   278853      stranraer, n/a, united kingdom  17.0
# 278854   278855  tacoma, washington, united kingdom  50.0
#
# [168096 rows x 3 columns]

# %%
books_df = pd.read_csv('Books.csv', dtype="string")
books_df = books_df.dropna().drop(books_df[books_df["Year-Of-Publication"] == '0'].index)
ratings_df = pd.read_csv('Ratings.csv')
ratings_df = ratings_df.dropna().drop_duplicates(subset=['User-ID', 'ISBN'], keep='last')

ratings_mean = ratings_df.groupby("ISBN").agg({'Book-Rating': 'mean', 'User-ID': 'count'}).rename(columns={'User-ID': 'Rating-Count'})
books_df = pd.merge(books_df, ratings_mean, on='ISBN', how='left')

# %%
popular = books_df.sort_values('Rating-Count', ascending=False)
popular.reset_index(drop=True, inplace=True)
popular.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0971880107                                        Wild Animus
# 1  0316666343                          The Lovely Bones: A Novel
# 2  0385504209                                  The Da Vinci Code
# 3  0060928336    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 4  0312195516                The Red Tent (Bestselling Backlist)
# 5  044023722X                                    A Painted House
# 6  0142001740                            The Secret Life of Bees
# 7  067976402X                             Snow Falling on Cedars
# 8  0671027360                                Angels &amp; Demons
# 9  0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
#
#       Book-Author Year-Of-Publication                Publisher  \
# 0    Rich Shapero                2004                  Too Far
# 1    Alice Sebold                2002            Little, Brown
# 2       Dan Brown                2003                Doubleday
# 3   Rebecca Wells                1997                Perennial
# 4   Anita Diamant                1998              Picador USA
# 5    John Grisham                2001  Dell Publishing Company
# 6   Sue Monk Kidd                2003            Penguin Books
# 7  David Guterson                1995        Vintage Books USA
# 8       Dan Brown                2001              Pocket Star
# 9    Billie Letts                1998             Warner Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0971880107.0...
# 1  http://images.amazon.com/images/P/0316666343.0...
# 2  http://images.amazon.com/images/P/0385504209.0...
# 3  http://images.amazon.com/images/P/0060928336.0...
# 4  http://images.amazon.com/images/P/0312195516.0...
# 5  http://images.amazon.com/images/P/044023722X.0...
# 6  http://images.amazon.com/images/P/0142001740.0...
# 7  http://images.amazon.com/images/P/067976402X.0...
# 8  http://images.amazon.com/images/P/0671027360.0...
# 9  http://images.amazon.com/images/P/0446672211.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0971880107.0...
# 1  http://images.amazon.com/images/P/0316666343.0...
# 2  http://images.amazon.com/images/P/0385504209.0...
# 3  http://images.amazon.com/images/P/0060928336.0...
# 4  http://images.amazon.com/images/P/0312195516.0...
# 5  http://images.amazon.com/images/P/044023722X.0...
# 6  http://images.amazon.com/images/P/0142001740.0...
# 7  http://images.amazon.com/images/P/067976402X.0...
# 8  http://images.amazon.com/images/P/0671027360.0...
# 9  http://images.amazon.com/images/P/0446672211.0...
#
#                                          Image-URL-L  Book-Rating  \
# 0  http://images.amazon.com/images/P/0971880107.0...     1.019584
# 1  http://images.amazon.com/images/P/0316666343.0...     4.468726
# 2  http://images.amazon.com/images/P/0385504209.0...     4.652322
# 3  http://images.amazon.com/images/P/0060928336.0...     3.448087
# 4  http://images.amazon.com/images/P/0312195516.0...     4.334716
# 5  http://images.amazon.com/images/P/044023722X.0...     3.187017
# 6  http://images.amazon.com/images/P/0142001740.0...     4.219512
# 7  http://images.amazon.com/images/P/067976402X.0...     3.255700
# 8  http://images.amazon.com/images/P/0671027360.0...     3.718430
# 9  http://images.amazon.com/images/P/0446672211.0...     4.105983
#
#    Rating-Count
# 0        2502.0
# 1        1295.0
# 2         883.0
# 3         732.0
# 4         723.0
# 5         647.0
# 6         615.0
# 7         614.0
# 8         586.0
# 9         585.0

# %%
highestRated = popular[popular["Rating-Count"] > 50].sort_values('Book-Rating', ascending=False)
highestRated.reset_index(drop=True, inplace=True)
highestRated.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 1  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 2  0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3  0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 4  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 5  0670894605                            The Secret Life of Bees
# 6  0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 7  0812550706      Ender's Game (Ender Wiggins Saga (Paperback))
# 8  0671027344                    The Perks of Being a Wallflower
# 9  0439139600       Harry Potter and the Goblet of Fire (Book 4)
#
#         Book-Author Year-Of-Publication              Publisher  \
# 0     J. K. Rowling                1999             Scholastic
# 1     J. K. Rowling                2000             Scholastic
# 2     J. K. Rowling                1999             Scholastic
# 3     J. K. Rowling                1998             Scholastic
# 4     J. K. Rowling                2003             Scholastic
# 5     Sue Monk Kidd                2002           Viking Books
# 6     J. K. Rowling                2001             Scholastic
# 7  Orson Scott Card                1994              Tor Books
# 8   Stephen Chbosky                1999                    MTV
# 9     J. K. Rowling                2002  Scholastic Paperbacks
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0439064864.0...
# 1  http://images.amazon.com/images/P/0439139597.0...
# 2  http://images.amazon.com/images/P/0439136350.0...
# 3  http://images.amazon.com/images/P/0590353403.0...
# 4  http://images.amazon.com/images/P/043935806X.0...
# 5  http://images.amazon.com/images/P/0670894605.0...
# 6  http://images.amazon.com/images/P/0439136369.0...
# 7  http://images.amazon.com/images/P/0812550706.0...
# 8  http://images.amazon.com/images/P/0671027344.0...
# 9  http://images.amazon.com/images/P/0439139600.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0439064864.0...
# 1  http://images.amazon.com/images/P/0439139597.0...
# 2  http://images.amazon.com/images/P/0439136350.0...
# 3  http://images.amazon.com/images/P/0590353403.0...
# 4  http://images.amazon.com/images/P/043935806X.0...
# 5  http://images.amazon.com/images/P/0670894605.0...
# 6  http://images.amazon.com/images/P/0439136369.0...
# 7  http://images.amazon.com/images/P/0812550706.0...
# 8  http://images.amazon.com/images/P/0671027344.0...
# 9  http://images.amazon.com/images/P/0439139600.0...
#
#                                          Image-URL-L  Book-Rating  \
# 0  http://images.amazon.com/images/P/0439064864.0...     6.611765
# 1  http://images.amazon.com/images/P/0439139597.0...     6.541237
# 2  http://images.amazon.com/images/P/0439136350.0...     6.467005
# 3  http://images.amazon.com/images/P/0590353403.0...     6.363095
# 4  http://images.amazon.com/images/P/043935806X.0...     5.571856
# 5  http://images.amazon.com/images/P/0670894605.0...     5.500000
# 6  http://images.amazon.com/images/P/0439136369.0...     5.345133
# 7  http://images.amazon.com/images/P/0812550706.0...     5.302564
# 8  http://images.amazon.com/images/P/0671027344.0...     5.194175
# 9  http://images.amazon.com/images/P/0439139600.0...     5.103627
#
#    Rating-Count
# 0         170.0
# 1         194.0
# 2         197.0
# 3         168.0
# 4         334.0
# 5          96.0
# 6         226.0
# 7         195.0
# 8         103.0
# 9         193.0

# %%
books_df[books_df["ISBN"] == '0439064864']
# Out:
#             ISBN                                        Book-Title  \
# 5334  0439064864  Harry Potter and the Chamber of Secrets (Book 2)
#
#         Book-Author Year-Of-Publication   Publisher  \
# 5334  J. K. Rowling                1999  Scholastic
#
#                                             Image-URL-S  \
# 5334  http://images.amazon.com/images/P/0439064864.0...
#
#                                             Image-URL-M  \
# 5334  http://images.amazon.com/images/P/0439064864.0...
#
#                                             Image-URL-L  Book-Rating  \
# 5334  http://images.amazon.com/images/P/0439064864.0...     6.611765
#
#       Rating-Count
# 5334         170.0
