# %%
import numpy as np
import pandas as pd

# %%
users_df = pd.read_csv('Users.csv')
users_df = users_df.dropna()
users_df
# Out:
#         User-ID                            Location   Age
# 1             2           stockton, california, usa  18.0
# 3             4           porto, v.n.gaia, portugal  17.0
# 5             6       santa monica, california, usa  61.0
# 9            10          albacete, wisconsin, spain  26.0
# 10           11      melbourne, victoria, australia  14.0
# ...         ...                                 ...   ...
# 278848   278849         georgetown, ontario, canada  23.0
# 278850   278851                  dallas, texas, usa  33.0
# 278851   278852     brisbane, queensland, australia  32.0
# 278852   278853      stranraer, n/a, united kingdom  17.0
# 278854   278855  tacoma, washington, united kingdom  50.0
#
# [168096 rows x 3 columns]

# %%
books_df = pd.read_csv('Books.csv', dtype="string")
books_df = books_df.dropna().drop(books_df[books_df["Year-Of-Publication"] == '0'].index)
ratings_df = pd.read_csv('Ratings.csv')
ratings_df = ratings_df.dropna().drop_duplicates(subset=['User-ID', 'ISBN'], keep='last')

ratings_mean = ratings_df.groupby("ISBN").agg({'Book-Rating': 'mean', 'User-ID': 'count'}).rename(columns={'User-ID': 'Rating-Count'})
books_df = pd.merge(books_df, ratings_mean, on='ISBN', how='left')

# %%
popular = books_df.sort_values('Rating-Count', ascending=False)
popular.reset_index(drop=True, inplace=True)
popular.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0971880107                                        Wild Animus
# 1  0316666343                          The Lovely Bones: A Novel
# 2  0385504209                                  The Da Vinci Code
# 3  0060928336    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 4  0312195516                The Red Tent (Bestselling Backlist)
# 5  044023722X                                    A Painted House
# 6  0142001740                            The Secret Life of Bees
# 7  067976402X                             Snow Falling on Cedars
# 8  0671027360                                Angels &amp; Demons
# 9  0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
#
#       Book-Author Year-Of-Publication                Publisher  \
# 0    Rich Shapero                2004                  Too Far
# 1    Alice Sebold                2002            Little, Brown
# ...

# %%
highestRated = popular[popular["Rating-Count"] > 50].sort_values('Book-Rating', ascending=False)
highestRated.reset_index(drop=True, inplace=True)
highestRated.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  1844262553                                               Free
# 1  0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 2  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 3  0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 4  0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 5  0618002227  The Fellowship of the Ring (The Lord of the Ri...
# 6  0385199570         The Stand (The Complete and Uncut Edition)
# 7  0877017883  Griffin &amp; Sabine: An Extraordinary Corresp...
# 8  0156528207                                  The Little Prince
# 9  039480001X                                 The Cat in the Hat
#
#                  Book-Author Year-Of-Publication  \
# 0               Paul Vincent                2003
# 1              J. K. Rowling                1999
# 2              J. K. Rowling                2000
# 3              J. K. Rowling                1999
# ...

# %%
books_df.set_index('ISBN', inplace=True)
books_df
# Out:
#                                                    Book-Title  \
# ISBN
# 0195153448                                Classical Mythology
# 0002005018                                       Clara Callan
# 0060973129                               Decision in Normandy
# 0374157065  Flu: The Story of the Great Influenza Pandemic...
# 0393045218                             The Mummies of Urumchi
# ...                                                       ...
# 0440400988                         There's a Bat in Bunk Five
# 0525447644                            From One to One Hundred
# 006008667X  Lily Dale : The True Story of the Town that Ta...
# 0192126040                        Republic (World's Classics)
# 0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                      Book-Author Year-Of-Publication  \
# ISBN
# 0195153448    Mark P. O. Morford                2002
# 0002005018  Richard Bruce Wright                2001
# ...

# %%
books_df.loc['0195153448']
# Out:
# Book-Title                                           Classical Mythology
# Book-Author                                           Mark P. O. Morford
# Year-Of-Publication                                                 2002
# Publisher                                        Oxford University Press
# Image-URL-S            http://images.amazon.com/images/P/0195153448.0...
# Image-URL-M            http://images.amazon.com/images/P/0195153448.0...
# Image-URL-L            http://images.amazon.com/images/P/0195153448.0...
# Book-Rating                                                          0.0
# Rating-Count                                                         1.0
# Name: 0195153448, dtype: object
