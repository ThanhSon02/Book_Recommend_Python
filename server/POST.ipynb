# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('Books.csv')
books
# Out:
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0440400988                         There's a Bat in Bunk Five
# 271355  0525447644                            From One to One Hundred
# 271356  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
books[(books['Year-Of-Publication'] == 'DK Publishing Inc') | (books['Year-Of-Publication'] == 'Gallimard')]
b
# Out:
#               ISBN                                         Book-Title  \
# 176     3150000335                                   Kabale Und Liebe
# 188     342311360X                            Die Liebe in Den Zelten
# 288     0571197639                        Poisonwood Bible Edition Uk
# 351     3596214629       Herr Der Fliegen (Fiction, Poetry and Drama)
# 542     8845229041  Biblioteca Universale Rizzoli: Sulla Sponda De...
# ...            ...                                                ...
# 270793  014029953X                         Foe (Essential.penguin S.)
# 270912  0340571187                                     Postmens House
# 271093  8427201079                           El Misterio De Sittaford
# 271181  0887781721                                          Tom Penny
# 271195  3150013763                                     Der Hofmeister
#
#                    Book-Author Year-Of-Publication  \
# 176                   Schiller                   0
# ...

# %%
row = [
  "a",
  "b",
  "c",
  2023,
  "d",
  "a",
  "a",
  "a"
]

# %%
temp = books[(books['Year-Of-Publication'] == 'DK Publishing Inc') | (books['Year-Of-Publication'] == 'Gallimard')]
authors = []
books_titles = []

for title in temp['Book-Title']:
    
    author = title.split(';')[-1].split('"')[0]
    book = title.split(';')[0].split('\\')[0]

    authors.append(author)
    books_titles.append(book)
cols_to_shift = books.columns[1:]
temp = pd.concat([temp['ISBN'].to_frame(), temp[cols_to_shift].shift(periods = 1, axis = 1)], axis=1)
temp['Book-Title'] = books_titles
temp['Book-Author'] = authors
rows_to_rem = list(temp.index)
books.drop(rows_to_rem, axis=0, inplace=True)
for ind in rows_to_rem:
    books.loc[ind] = list(temp.loc[ind].values)

# %%
books_df.loc[len(books_df)] = row
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14832/4046069378.py in <module>
# ----> 1 books_df.loc[len(books_df)] = row
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# ...

# %%
books_df.sort_values('ISBN')
# Out:
#               ISBN                                         Book-Title  \
# 254243  0000913154  The Way Things Work: An Illustrated Encycloped...
# 215802  0001010565                                    Mog's Christmas
# 42562   0001046438                                               Liar
# 112555  0001046713                       Twopence to Cross the Mersey
# 42604   000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...
# ...            ...                                                ...
# 72805   B000234N76                                     Falling Angels
# 193526  B000234NC6  It Must've Been Something I Ate: The Return of...
# 131085  B00029DGGO                        Good Wife Strikes Back, The
# 179422  B0002JV9PY                               The Blockade Runners
# 179420  B0002K6K8O                               The Underground City
#
#                           Book-Author  Year-Of-Publication  \
# 254243  C. van Amerongen (translator)                 1967
# ...

# %%
books_df[books_df['ISBN'] == '0195153448']
# Out:
#          ISBN           Book-Title         Book-Author  Year-Of-Publication  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford                 2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
'0195153448' in np.array(books_df['ISBN'])
# Out:
# True

# %%
users_df = pd.read_csv('Users.csv')

# %%
users_df
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings_df = pd.read_csv('Ratings.csv')
ratings_df
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X          8.0
# 1         276726   0155061224          5.0
# 2         276727   0446520802          0.0
# 3         276729   052165615X          3.0
# 4         276729   0521795028          6.0
# ...          ...          ...          ...
# 1149777   276709   0515107662         10.0
# 1149778   276721   0590442449         10.0
# 1149779   276723  05162443314          8.0
# 1149780        1   0195153448          7.0
# 1149781        1   0155061224          6.0
#
# [1149782 rows x 3 columns]

# %%
ratings_df[ratings_df["User-ID"] == 2]
# Out:
#       User-ID        ISBN  Book-Rating
# 9561        2  0195153448            6

# %%
ratings_df.sort_values('User-ID')
# Out:
#          User-ID        ISBN  Book-Rating
# 1149780        1  0195153448          7.0
# 9561           2  0195153448          6.0
# 9562           7   034542252          0.0
# 9580           8  1881320189          7.0
# 9579           8  1575663937          6.0
# ...          ...         ...          ...
# 9560      278854  0553579606          8.0
# 9554      278854  0375703063          7.0
# 9553      278854  0316184152          7.0
# 9555      278854  042516098X          7.0
# 9559      278854  0553578596          0.0
#
# [1149781 rows x 3 columns]

# %%
ratings = ratings_df.copy()
ratings.loc[(ratings['ISBN'] == '034545104X') & (ratings['User-ID'] == 1), 'Book-Rating'] = 8
row = ratings[(ratings['ISBN'] == '034545104X') & (ratings['User-ID'] == 1)]
row
# Out:
# Empty DataFrame
# Columns: [User-ID, ISBN, Book-Rating]
# Index: []

# %%
row = ['1', '0155061224', 6]
ratings.loc[len(ratings)] = row
ratings
# Out:
#         User-ID         ISBN  Book-Rating
# 0        276725   034545104X          8.0
# 1        276726   0155061224          5.0
# 2        276727   0446520802          0.0
# 3        276729   052165615X          3.0
# 4        276729   0521795028          6.0
# ...         ...          ...          ...
# 1149777  276709   0515107662         10.0
# 1149778  276721   0590442449         10.0
# 1149779  276723  05162443314          8.0
# 1149780       1   0195153448          7.0
# 1149781       1   0155061224          6.0
#
# [1149782 rows x 3 columns]

# %%
ratings.to_csv('Ratings.csv', index=False)

# %%
a = pd.read_csv('Ratings.csv')
a
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X          8.0
# 1         276726   0155061224          5.0
# 2         276727   0446520802          0.0
# 3         276729   052165615X          3.0
# 4         276729   0521795028          6.0
# ...          ...          ...          ...
# 1149776   276706   0679447156          0.0
# 1149777   276709   0515107662         10.0
# 1149778   276721   0590442449         10.0
# 1149779   276723  05162443314          8.0
# 1149780        1   034545104X          8.0
#
# [1149781 rows x 3 columns]
