# %%
import pandas as pd
import numpy as np

# %%
books_df = pd.read_csv('Books.csv')

# %%
books_df.sort_values('ISBN')
# Out:
#               ISBN                                         Book-Title  \
# 254243  0000913154  The Way Things Work: An Illustrated Encycloped...
# 215802  0001010565                                    Mog's Christmas
# 42562   0001046438                                               Liar
# 112555  0001046713                       Twopence to Cross the Mersey
# 42604   000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...
# ...            ...                                                ...
# 72805   B000234N76                                     Falling Angels
# 193526  B000234NC6  It Must've Been Something I Ate: The Return of...
# 131085  B00029DGGO                        Good Wife Strikes Back, The
# 179422  B0002JV9PY                               The Blockade Runners
# 179420  B0002K6K8O                               The Underground City
#
#                           Book-Author  Year-Of-Publication  \
# 254243  C. van Amerongen (translator)                 1967
# ...

# %%
books_df[books_df['ISBN'] == '0195153448']
# Out:
#          ISBN           Book-Title         Book-Author  Year-Of-Publication  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford                 2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
'0195153448' in np.array(books_df['ISBN'])
# Out:
# True

# %%
users_df = pd.read_csv('Users.csv')

# %%
users_df
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings_df = pd.read_csv('Ratings.csv')

# %%
ratings_df[ratings_df["User-ID"] == 2]
# Out:
#       User-ID        ISBN  Book-Rating
# 9561        2  0195153448            6

# %%
ratings_df.sort_values('User-ID')
# Out:
#       User-ID        ISBN  Book-Rating
# 9561        2  0195153448            6
# 9562        7   034542252            0
# 9572        8  0771025661            0
# 9580        8  1881320189            7
# 9579        8  1575663937            6
# ...       ...         ...          ...
# 9560   278854  0553579606            8
# 9554   278854  0375703063            7
# 9553   278854  0316184152            7
# 9555   278854  042516098X            7
# 9559   278854  0553578596            0
#
# [1149780 rows x 3 columns]

# %%
ratings_df.loc[(ratings_df['ISBN'] == '034545104X') & (ratings_df['User-ID'] == 276725), 'Book-Rating'] = 7
row = ratings_df[(ratings_df['ISBN'] == '034545104X') & (ratings_df['User-ID'] == 276725)]
row
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            7

# %%
row = {'User-ID': '1', 'ISBN': '0195153448', 'Book-Rating': 7}
ratings_df.append(row, ignore_index=True)
# Out:
#         User-ID         ISBN  Book-Rating
# 0        276725   034545104X            0
# 1        276726   0155061224            5
# 2        276727   0446520802            0
# 3        276729   052165615X            3
# 4        276729   0521795028            6
# ...         ...          ...          ...
# 1149776  276706   0679447156            0
# 1149777  276709   0515107662           10
# 1149778  276721   0590442449           10
# 1149779  276723  05162443314            8
# 1149780       1   0195153448            7
#
# [1149781 rows x 3 columns]

# %%
ratings_df.to_csv('Ratings.csv', index=False)

# %%
1149780
